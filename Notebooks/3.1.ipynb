# %% [markdown]
# # 🧠 Predicción de Riesgo de Crédito – German Credit Dataset
#
# ## 📌 Contexto del problema
#
# Cuando un banco recibe una solicitud de préstamo, debe decidir si aprueba o no el crédito con base en el perfil del solicitante. Existen dos tipos de riesgo:
#
# - Si el solicitante es un **buen riesgo crediticio** (es decir, probablemente pagará), y se **rechaza** su solicitud, el banco **pierde una oportunidad de negocio**.
# - Si el solicitante es un **mal riesgo crediticio** (es decir, probablemente no pagará), y se **aprueba** su solicitud, el banco **asume una pérdida financiera**.
#
# Este dataset incluye 1000 registros con 20 variables predictoras, además de la clasificación `Creditability` (bueno o malo), que es lo que intentaremos predecir.
#
# ---
# ## 🕰️ Consideraciones históricas y monetarias
#
# Este dataset fue recolectado antes de la adopción del euro (€) como moneda oficial en Alemania. Por lo tanto:
#
# - Todas las cantidades monetarias (como `Credit_Amount`, `Savings/Stocks`, etc.) están expresadas en **marcos alemanes (Deutsche Mark, DM)**.
# - Alemania cambió al euro en el año **2002**, y el tipo de cambio final fue:
#   > **1 EUR = 1.95583 DM**
#
# Aunque no es necesario convertir las cantidades a euros para el análisis (ya que se trabajará con modelos relativos), **es importante tener presente este contexto**:
#
# - Las cifras no representan montos actuales.
# - Los rangos de ingreso, empleo y ahorro deben interpretarse en relación al estándar de vida en Alemania antes del 2002.
# - Este detalle puede influir en la interpretación del poder adquisitivo y la clasificación del riesgo crediticio en su momento.
#
# 🔎 *Conclusión: trabajaremos con las cifras tal como están, pero entendiendo que no corresponden al valor monetario moderno.*
#
# ---
#
# ## 🧾 Diccionario completo de variables
#
# - `Creditability`: Variable objetivo.
#   1 = Buen riesgo crediticio
#   0 = Mal riesgo crediticio
#
# - `Account_Balance`: Estado de la cuenta bancaria
#   1 = Sin cuenta
#   2 = Menos de 0 DM
#   3 = Entre 0 y 200 DM
#   4 = Más de 200 DM o salario recibido por transferencia
#
# - `Duration_of_Credit_monthly`: Duración del crédito en meses (variable numérica)
#
# - `Payment_Status_of_Previous_Credit`: Estado de pagos anteriores
#   0 = Ninguno / sin historial
#   1 = Retrasos o problemas críticos
#   2 = Demoras leves o esporádicas
#   3 = Pagos al día
#   4 = Sin deudas
#
# - `Purpose`: Motivo del crédito
#   0 = No especificado
#   1 = Carro nuevo
#   2 = Usado
#   3 = Muebles
#   4 = Radio/televisión
#   5 = Electrodomésticos
#   6 = Reparaciones
#   8 = Vacaciones
#   9 = Renovaciones
#   10 = Educación
#
# - `Credit_Amount`: Monto del crédito solicitado (en Deutsche Mark - DM)
#
# - `Value_Savings_Stocks`: Valor de ahorros/inversiones
#   1 = Ninguno
#   2 = Menos de 100 DM
#   3 = Entre 100 y 500 DM
#   4 = Entre 500 y 1000 DM
#   5 = Más de 1000 DM
#
# - `Length_of_current_employment`: Antigüedad laboral
#   1 = Desempleado / <1 año
#   2 = 1 a <4 años
#   3 = 4 a <7 años
#   4 = 7 a <10 años
#   5 = Más de 10 años
#
# - `Instalment_per_cent`: Porcentaje de la cuota mensual respecto al ingreso (valor entre 1 y 4)
#
# - `Sex_Marital_Status`: Género y estado civil
#   1 = Hombre soltero/divorciado
#   2 = Hombre casado/viudo
#   3 = Mujer soltera
#   4 = Mujer casada
#
# - `Guarantors`: Avales
#   1 = Ninguno
#   2 = Cónyuge
#   3 = Otro garante
#
# - `Duration_in_Current_address`: Tiempo en años en la residencia actual
#
# - `Most_valuable_available_asset`: Bien más valioso disponible
#   1 = Auto propio
#   2 = Seguro de vida
#   3 = Bien inmueble
#   4 = Ninguno
#
# - `Age_years`: Edad del solicitante (años)
#
# - `Concurrent_Credits`: Otros créditos activos
#   1 = Ninguno
#   2 = Tiendas
#   3 = Otros bancos
#
# - `Type_of_apartment`: Tipo de vivienda
#   1 = Alquilada
#   2 = Propia
#   3 = Sin costo
#
# - `No_of_Credits_at_this_Bank`: Número de créditos actuales con el banco
#
# - `Occupation`: Ocupación
#   1 = Desempleado / no calificado
#   2 = Obrero calificado
#   3 = Empleado / funcionario
#   4 = Autónomo / alta calificación
#
# - `No_of_dependents`: Número de personas a cargo (1 o 2)
#
# - `Telephone`: Teléfono registrado
#   1 = No
#   2 = Sí
#
# - `Foreign_Worker`: ¿Es trabajador extranjero?
#   1 = Sí
#   2 = No
#
# ---
#
# ## 📚 Fuente y referencia
#
# Este dataset es parte del curso *Stat 508* de Penn State University.
# 📎 [Documentación oficial del dataset](https://online.stat.psu.edu/stat508/resource/analysis/gcd)

# %%
# Librerías principales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar dataset
df = pd.read_csv("../data/Credit_Data.csv", sep=';')

# %% [markdown]
# # 🧩 Analisis de los datos cargados
#
# Despues de cargar los Datos procedemos a analizar los datos obtenidos del dataset con el fin de identificar si hay datos nulos o incompletos

# %%
df.head()
# Out:
#    Creditability  Account_Balance  Duration_of_Credit_monthly  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment_Status_of_Previous_Credit  Purpose  Credit_Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value_Savings_Stocks  Length_of_current_employment  Instalment_per_cent  \
# 0                     1                             2                    4
# ...

# %% [markdown]
# Inicialmente podemos evidenciar que se cargo el dataset de manera correcta evidenciando algunos datos y las 21 columnas que contiene

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   int64
#  1   Account_Balance                    1000 non-null   int64
#  2   Duration_of_Credit_monthly         1000 non-null   int64
#  3   Payment_Status_of_Previous_Credit  1000 non-null   int64
#  4   Purpose                            1000 non-null   int64
#  5   Credit_Amount                      1000 non-null   int64
#  6   Value_Savings_Stocks               1000 non-null   int64
#  7   Length_of_current_employment       1000 non-null   int64
#  8   Instalment_per_cent                1000 non-null   int64
#  9   Sex_Marital_Status                 1000 non-null   int64
#  10  Guarantors                         1000 non-null   int64
# ...

# %% [markdown]
# Con esta función logramos identificar en primer lugar que no hay datos vacios, es decir que todas las filas del dataset nos van a servir para el analisís, por otro lado tenemos que todos los datos de las columnas son de tipo numerico, por lo tanto para su desarrollo vamos a seguir el diccionario que mostramos en la parte superior del documento.

# %%
df.describe()
# Out:
#        Creditability  Account_Balance  Duration_of_Credit_monthly  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment_Status_of_Previous_Credit      Purpose  Credit_Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# ...

# %% [markdown]
# Con esta función ya aplicamos un poco mas de estadistica descritiva en donde encontramos el promedio de las variables junto a su desviación estandar, ademas que los cuartiles donde podemos ver que tan dispersos estan los datos en los cuartiles descritos.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Aqui nos damos cuenta que no tenemos ningun dato repetido dentro del dataset

# %%
# Lista de columnas categóricas codificadas con números
categorical_cols = [
    'Creditability',  # Variable objetivo binaria
    'Account_Balance',
    'Payment_Status_of_Previous_Credit',
    'Purpose',
    'Value_Savings_Stocks',
    'Length_of_current_employment',
    'Instalment_per_cent',
    'Sex_Marital_Status',
    'Guarantors',
    'Most_valuable_available_asset',
    'Concurrent_Credits',
    'Type_of_apartment',
    'No_of_Credits_at_this_Bank',
    'Occupation',
    'No_of_dependents',
    'Duration_in_Current_address',
    'Telephone',
    'Foreign_Worker'
]


# Convertirlas a tipo 'category'
for col in categorical_cols:
    df[col] = df[col].astype('category')
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   category
#  1   Account_Balance                    1000 non-null   category
#  2   Duration_of_Credit_monthly         1000 non-null   int64
#  3   Payment_Status_of_Previous_Credit  1000 non-null   category
#  4   Purpose                            1000 non-null   category
#  5   Credit_Amount                      1000 non-null   int64
#  6   Value_Savings_Stocks               1000 non-null   category
#  7   Length_of_current_employment       1000 non-null   category
#  8   Instalment_per_cent                1000 non-null   category
#  9   Sex_Marital_Status                 1000 non-null   category
#  10  Guarantors                         1000 non-null   category
# ...

# %% [markdown]
# Ahora empezamos con un tratamiento de datos de tal forma que las que antes eran variables numericas las converitimos en categorica y mantenemos en enteras las variables que son netamente valores.

# %% [markdown]
# ## Comprobamos los Diccionarios

# %%
# Validar códigos para Account_Balance (esperados: 1–4)
for col in categorical_cols:
    print(df[col].value_counts().sort_index())
# Out:
# Creditability
# 0    300
# 1    700
# Name: count, dtype: int64
# Account_Balance
# 1    274
# 2    269
# 3     63
# 4    394
# Name: count, dtype: int64
# Payment_Status_of_Previous_Credit
# 0     40
# 1     49
# 2    530
# 3     88
# 4    293
# Name: count, dtype: int64
# Purpose
# 0     234
# 1     103
# 2     181
# 3     280
# 4      12
# 5      22
# 6      50
# 8       9
# 9      97
# 10     12
# Name: count, dtype: int64
# Value_Savings_Stocks
# 1    603
# 2    103
# 3     63
# 4     48
# 5    183
# Name: count, dtype: int64
# Length_of_current_employment
# 1     62
# 2    172
# 3    339
# 4    174
# 5    253
# Name: count, dtype: int64
# Instalment_per_cent
# 1    136
# 2    231
# 3    157
# 4    476
# Name: count, dtype: int64
# Sex_Marital_Status
# 1     50
# 2    310
# 3    548
# 4     92
# Name: count, dtype: int64
# Guarantors
# 1    907
# 2     41
# 3     52
# Name: count, dtype: int64
# Most_valuable_available_asset
# 1    282
# 2    232
# 3    332
# 4    154
# ...

# %% [markdown]
# De esta forma comprobamos que todas las variables categoricas estan realcionadas con su diccionario

# %% [markdown]
# # Pasamos a verificar los rangos en las variables numericas

# %%
print(df['Age_years'].describe())
# Out:
# count    1000.00000
# mean       35.54200
# std        11.35267
# min        19.00000
# 25%        27.00000
# 50%        33.00000
# 75%        42.00000
# max        75.00000
# Name: Age_years, dtype: float64

# %% [markdown]
# Para la variable Duration_of_Credit_monthly, denotamos que la edad minima del dataset es 19 años lo cual concuerda con lo estimado a pedir un credito apenas se cumple los 18, por otro lado vemos que la edad mas longeva que hay dentro del dataset es de 75 por lo que tenemos que la edad entre el dataset es de 19 a 75 .

# %%
print(df['Duration_of_Credit_monthly'].describe())
# Out:
# count    1000.000000
# mean       20.903000
# std        12.058814
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        24.000000
# max        72.000000
# Name: Duration_of_Credit_monthly, dtype: float64

# %% [markdown]
# Para la variable Duration_of_Credit_monthly, denotamos que la duración minima de un credito dentro del dataset es 4 meses y por otro lado vemos que la duración maxima de los creditos dentro del dataset es de 72.

# %%
print(df['Credit_Amount'].describe())
# Out:
# count     1000.00000
# mean      3271.24800
# std       2822.75176
# min        250.00000
# 25%       1365.50000
# 50%       2319.50000
# 75%       3972.25000
# max      18424.00000
# Name: Credit_Amount, dtype: float64

# %% [markdown]
# Para la variable Credit_Amount, denotamos que el valor minimo dentro de una cuenta dentro del dataset es 250 Deutsche Mark(DM) y por otro lado vemos que el valor maximo dentro de una cuenta es de 18424 Deutsche Mark(DM).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Credit_Amount'], bins=60)
plt.title("Distribución del Monto de Crédito")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Duration_of_Credit_monthly'], bins=60)
plt.title("Distribución de la Duración de los creditos")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Age_years'], bins=60)
plt.title("Distribución del edades con un credito en el banco")
plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x=col)
    plt.title(f'Frecuencia de {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# Frecuencia absoluta
df['Creditability'].value_counts()
# Out:
# Creditability
# 1    70.0
# 0    30.0
# Name: proportion, dtype: float64

# %%
# Frecuencia relativa
df['Creditability'].value_counts(normalize=True) * 100
# Out:
# Creditability
# 1    70.0
# 0    30.0
# Name: proportion, dtype: float64

# %% [markdown]
# ### 🧠 Análisis de la variable objetivo – `Creditability`
#
# La variable `Creditability` representa si un solicitante es considerado un buen riesgo crediticio (`1`) o un mal riesgo (`0`).
#
# - El **70% de los casos** corresponden a buenos pagadores.
# - El **30% de los casos** son malos pagadores o personas con riesgo de incumplimiento.
#
# 📌 Esto indica que el dataset está **moderadamente desbalanceado**. Aunque no es extremo, podría influir en el rendimiento de algunos modelos de clasificación (como la regresión logística), que tienden a favorecer la clase mayoritaria.
# Es importante tener esto en cuenta para aplicar técnicas de balanceo si es necesario en fases posteriores.

# %%
# Ejemplo: Crédito total según creditabilidad
sns.boxplot(data=df, x='Creditability', y='Credit_Amount')
plt.title("Monto de crédito según el riesgo")
plt.show()

# %%
# Ejemplo: Crédito total según creditabilidad
sns.boxplot(data=df, x='Creditability', y='Age_years')
plt.title("Edad de la persona que pide el prestamo según el  riesgo")
plt.show()

# %%
# Ejemplo: Crédito total según creditabilidad
sns.boxplot(data=df, x='Creditability', y='Duration_of_Credit_monthly')
plt.title("Duración del Credito según el riesgo")
plt.show()

# %% [markdown]
# ### 📊 Relación entre variables numéricas y `Creditability`
#
# Se exploraron tres variables numéricas clave en función del riesgo crediticio (`Creditability`):
#
# #### 🟦 1. `Credit_Amount`
# - Se observa que los solicitantes con menor `Creditability` (riesgo alto, valor 0) tienden a solicitar montos de crédito ligeramente mayores.
# - Hay una mayor concentración de outliers (montos extremos) en esta clase, lo cual podría estar asociado al incumplimiento.
#
# #### 🟦 2. `Age_years`
# - La edad media de los solicitantes no muestra una diferencia muy marcada entre clases.
# - Sin embargo, la dispersión parece ligeramente mayor entre los buenos pagadores, lo que sugiere que hay perfiles de riesgo en múltiples grupos de edad.
#
# #### 🟦 3. `Credit_Duration_Months`
# - Los malos pagadores (`Creditability` = 0) tienden a tener una duración de crédito más prolongada.
# - Esta variable podría ser predictiva, ya que un mayor plazo puede implicar mayor riesgo de incumplimiento.
#
# 📌 En resumen, variables como **`Credit_Amount` y `Credit_Duration_Months`** muestran una mayor diferenciación según el riesgo, y podrían ser relevantes para el modelo.

# %%
from scipy.stats import ttest_ind, chi2_contingency

variables = ['Credit_Amount', 'Age_years', 'Duration_of_Credit_monthly']

for var in variables:
    group1 = df[df['Creditability'] == 1][var]
    group0 = df[df['Creditability'] == 0][var]
    t_stat, p_val = ttest_ind(group1, group0, equal_var=False)
    print(f"{var}: t = {t_stat:.3f}, p = {p_val:.4f}")
# Out:
# Credit_Amount: t = -4.264, p = 0.0000
# Age_years: t = 2.908, p = 0.0038
# Duration_of_Credit_monthly: t = -6.470, p = 0.0000

# %% [markdown]
# ### 🧪 Prueba t de Student – Comparación de medias entre grupos (`Creditability`)
#
# Se aplicó una prueba t para muestras independientes (Welch's t-test) para comparar las medias de variables numéricas clave entre:
#
# - Grupo 1: solicitantes considerados buen riesgo (`Creditability = 1`)
# - Grupo 0: solicitantes considerados mal riesgo (`Creditability = 0`)
#
# #### 📌 Resultados:
#
# | Variable                     | t-statistic | p-valor  | Interpretación                                  |
# |-----------------------------|-------------|----------|------------------------------------------------|
# | `Credit_Amount`             | -4.264      | 0.0000   | Diferencia significativa: los malos pagadores tienden a solicitar montos mayores. |
# | `Age_years`                 | 2.908       | 0.0038   | Diferencia significativa: los buenos pagadores son, en promedio, un poco mayores. |
# | `Duration_of_Credit_monthly`| -6.470      | 0.0000   | Diferencia significativa: los malos pagadores tienen créditos más largos. |
#
# ✅ En todos los casos, el p-valor < 0.05, por lo tanto **rechazamos la hipótesis nula**: existe evidencia estadística de que las medias difieren entre los dos grupos.
#
# Estas variables pueden ser relevantes para predecir el riesgo crediticio y deberían considerarse en la fase de modelado.

# %%
categorical_cols = [
    'Account_Balance',
    'Payment_Status_of_Previous_Credit',
    'Purpose',
    'Value_Savings_Stocks',
    'Length_of_current_employment',
    'Instalment_per_cent',
    'Sex_Marital_Status',
    'Guarantors',
    'Most_valuable_available_asset',
    'Concurrent_Credits',
    'Type_of_apartment',
    'No_of_Credits_at_this_Bank',
    'Occupation',
    'No_of_dependents',
    'Duration_in_Current_address',
    'Telephone',
    'Foreign_Worker'
]

# Aplicar prueba chi-cuadrado para cada una
for col in categorical_cols:
    table = pd.crosstab(df[col], df['Creditability'])
    chi2, p, dof, expected = chi2_contingency(table)
    print(f"{col}: chi2 = {chi2:.2f}, p = {p:.4f}")
# Out:
# Creditability: chi2 = 995.24, p = 0.0000
# Account_Balance: chi2 = 123.72, p = 0.0000
# Payment_Status_of_Previous_Credit: chi2 = 61.69, p = 0.0000
# Purpose: chi2 = 33.36, p = 0.0001
# Value_Savings_Stocks: chi2 = 36.10, p = 0.0000
# Length_of_current_employment: chi2 = 18.37, p = 0.0010
# Instalment_per_cent: chi2 = 5.48, p = 0.1400
# Sex_Marital_Status: chi2 = 9.61, p = 0.0222
# Guarantors: chi2 = 6.65, p = 0.0361
# Most_valuable_available_asset: chi2 = 23.72, p = 0.0000
# Concurrent_Credits: chi2 = 12.84, p = 0.0016
# Type_of_apartment: chi2 = 18.67, p = 0.0001
# No_of_Credits_at_this_Bank: chi2 = 2.67, p = 0.4451
# Occupation: chi2 = 1.89, p = 0.5966
# No_of_dependents: chi2 = 0.00, p = 1.0000
# Duration_in_Current_address: chi2 = 0.75, p = 0.8616
# Telephone: chi2 = 1.17, p = 0.2789
# Foreign_Worker: chi2 = 5.82, p = 0.0158

# %% [markdown]
# ### 📊 Prueba Chi-cuadrado – Asociación entre variables categóricas y `Creditability`
#
# Se realizó una prueba Chi-cuadrado de independencia entre la variable objetivo (`Creditability`) y las variables categóricas del dataset, para determinar si existe relación estadística entre ellas.
#
# #### 📌 Resultados:
#
# | Variable                          | χ² (chi2) | p-valor | ¿Asociación significativa? | Interpretación breve |
# |----------------------------------|-----------|---------|-----------------------------|-----------------------|
# | `Account_Balance`                | 123.72    | 0.0000  | ✅ Sí                        | Fuerte relación entre saldo de cuenta y riesgo. |
# | `Payment_Status_of_Previous_Credit` | 61.69     | 0.0000  | ✅ Sí                        | Historial de pagos influye claramente. |
# | `Purpose`                        | 33.36     | 0.0001  | ✅ Sí                        | El motivo del crédito tiene influencia. |
# | `Value_Savings_Stocks`           | 36.10     | 0.0000  | ✅ Sí                        | Nivel de ahorro se asocia al riesgo. |
# | `Length_of_current_employment`   | 18.37     | 0.0010  | ✅ Sí                        | Mayor antigüedad reduce el riesgo. |
# | `Instalment_per_cent`            | 5.48      | 0.1400  | ❌ No                        | No se observa relación clara. |
# | `Sex_Marital_Status`             | 9.61      | 0.0222  | ✅ Sí                        | Influencia leve del género y estado civil. |
# | `Guarantors`                     | 6.65      | 0.0361  | ✅ Sí                        | Tener aval se relaciona con el riesgo. |
# | `Most_valuable_available_asset`  | 23.72     | 0.0000  | ✅ Sí                        | El activo disponible influye fuertemente. |
# | `Concurrent_Credits`             | 12.84     | 0.0016  | ✅ Sí                        | Otros créditos afectan la evaluación. |
# | `Type_of_apartment`              | 18.67     | 0.0001  | ✅ Sí                        | Tipo de vivienda es relevante. |
# | `No_of_Credits_at_this_Bank`     | 2.67      | 0.4451  | ❌ No                        | No parece influir significativamente. |
# | `Occupation`                     | 1.89      | 0.5966  | ❌ No                        | No se observa asociación estadística. |
# | `No_of_dependents`               | 0.00      | 1.0000  | ❌ No                        | Número de dependientes no tiene impacto. |
# | `Duration_in_Current_address`    | 0.75      | 0.8616  | ❌ No                        | Duración en la vivienda no es significativa. |
# | `Telephone`                      | 1.17      | 0.2789  | ❌ No                        | No hay relación evidente. |
# | `Foreign_Worker`                 | 5.82      | 0.0158  | ✅ Sí                        | Influencia leve del estatus de extranjero. |
#
# ---
#
# ✅ **Conclusión:**
# De 17 variables evaluadas, **12 muestran asociación estadísticamente significativa** con la variable `Creditability`.
# Las demás pueden considerarse prescindibles o ser revaluadas durante la selección de características.

# %% [markdown]
# ### 📌 Insights relevantes del análisis exploratorio
#
# - La mayoría de las variables categóricas están estadísticamente relacionadas con la capacidad de pago (`Creditability`), especialmente `Account_Balance`, `Payment_Status_of_Previous_Credit` y `Purpose`.
# - Las variables numéricas `Credit_Amount` y `Duration_of_Credit_monthly` están asociadas a mayor riesgo de incumplimiento: los solicitantes de mayor monto y mayor plazo son más propensos a ser malos pagadores.
# - Variables como `Occupation`, `Telephone` y `No_of_dependents` no mostraron relación estadística significativa, por lo que podrían descartarse o necesitar transformación adicional.
# - Los activos disponibles (`Most_valuable_available_asset`) y la antigüedad laboral también son buenos indicadores del riesgo.
